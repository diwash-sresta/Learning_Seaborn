# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = sns.load_dataset('tips')
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df,hue='sex',kind='reg',markers=['*','o'])# scatter , reg, kde, hist
plt.show()
